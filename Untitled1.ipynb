# %%
# Dados simulados
temperatura_interna = 25
temperatura_externa = 30
integridade = 1
energia = 80
pressao = 5
modulos_ok = True

# Verificação
if (20 <= temperatura_interna <= 30 and
    -10 <= temperatura_externa <= 40 and
    integridade == 1 and
    energia > 50 and
    3 <= pressao <= 7 and
    modulos_ok):

    print("PRONTO PARA DECOLAR")
else:
    print("DECOLAGEM ABORTADA")
